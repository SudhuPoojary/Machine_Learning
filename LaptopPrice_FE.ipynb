# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Laptops- Buy Products Online at Best Price in India - All Categories _ Flipkart.com.csv")

# %%
df.head()
# Out:
#                                                Title  Rating    Price  \
# 0  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...     4.5  ₹35,990
# 1  Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 ...     4.3  ₹62,990
# 2  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.3  ₹43,490
# 3  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...     4.3  ₹36,990
# 4  HP Pavilion Core i5 11th Gen - (8 GB/512 GB SS...     4.8  ₹59,990
#
#             Series          color                              power_backup  \
# 0          15IML05      IdeaPad 3                 Processing & Multitasking
# 1  Ideapad Slim 5i  Graphite Grey                             Upto 11 Hours
# 2        IdeaPad 3    Arctic Grey                              Upto 6 Hours
# 3        IdeaPad 3  Platinum Grey                              Upto 9 hours
# 4      14-dv0543TU       Pavilion  Entertainment, Processing & Multitasking
#
#   processor_brand processor  ssd     ram ram_type hardsk_capacity  \
# ...

# %%
that = "Pavilion"

# %%
df["Pavilion"] = df['color'].str.find(that)

# %%
df.head()
# Out:
#                                                Title  Rating    Price  \
# 0  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...     4.5  ₹35,990
# 1  Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 ...     4.3  ₹62,990
# 2  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.3  ₹43,490
# 3  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...     4.3  ₹36,990
# 4  HP Pavilion Core i5 11th Gen - (8 GB/512 GB SS...     4.8  ₹59,990
#
#             Series          color                              power_backup  \
# 0          15IML05      IdeaPad 3                 Processing & Multitasking
# 1  Ideapad Slim 5i  Graphite Grey                             Upto 11 Hours
# 2        IdeaPad 3    Arctic Grey                              Upto 6 Hours
# 3        IdeaPad 3  Platinum Grey                              Upto 9 hours
# 4      14-dv0543TU       Pavilion  Entertainment, Processing & Multitasking
#
#   processor_brand processor  ssd     ram ram_type hardsk_capacity  \
# ...

# %%
x = df.pop('Pavilion')

# %%
df.head()
# Out:
#                                                Title  Rating    Price  \
# 0  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...     4.5  ₹35,990
# 1  Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 ...     4.3  ₹62,990
# 2  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.3  ₹43,490
# 3  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...     4.3  ₹36,990
# 4  HP Pavilion Core i5 11th Gen - (8 GB/512 GB SS...     4.8  ₹59,990
#
#             Series          color                              power_backup  \
# 0          15IML05      IdeaPad 3                 Processing & Multitasking
# 1  Ideapad Slim 5i  Graphite Grey                             Upto 11 Hours
# 2        IdeaPad 3    Arctic Grey                              Upto 6 Hours
# 3        IdeaPad 3  Platinum Grey                              Upto 9 hours
# 4      14-dv0543TU       Pavilion  Entertainment, Processing & Multitasking
#
#   processor_brand processor  ssd     ram ram_type hardsk_capacity  \
# ...

# %%
x = x.replace(to_replace= -1, value= 0)

# %%
x = x.replace(to_replace= 0, value= 1)

# %%
x
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 156    1
# 157    1
# 158    1
# 159    1
# 160    1
# Name: Pavilion, Length: 161, dtype: int64

# %%
df = pd.read_csv("filename.csv")
df.head()
this = "variable"
df["variable"]= def["which column"].str.find(this)
df.head()
x = df.pop("varibles")
df.head()
x = x.replace(to_replace = -1, value = 0)
x = x.replace(to_replace = 0, value = 1)
x
